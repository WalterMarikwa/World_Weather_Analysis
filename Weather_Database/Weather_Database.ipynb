# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | oranjemund
# Processing Record 9 of Set 1 | galle
# Processing Record 10 of Set 1 | narsaq
# Processing Record 11 of Set 1 | vardo
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | ithaca
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | santa maria da vitoria
# Processing Record 17 of Set 1 | jaciara
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | tisul
# Processing Record 22 of Set 1 | pangody
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | fairbanks
# Processing Record 27 of Set 1 | krasnoselkup
# Processing Record 28 of Set 1 | toda bhim
# City not found. Skipping...
# Processing Record 29 of Set 1 | holoby
# Processing Record 30 of Set 1 | teshie
# Processing Record 31 of Set 1 | lasa
# Processing Record 32 of Set 1 | newport
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | susanville
# Processing Record 37 of Set 1 | kununurra
# Processing Record 38 of Set 1 | maxixe
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | yulara
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 46 of Set 1 | mongua
# Processing Record 47 of Set 1 | kandrian
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | vila
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | mezen
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | namibe
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | hauterive
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | flinders
# Processing Record 9 of Set 2 | novoagansk
# Processing Record 10 of Set 2 | lagos
# Processing Record 11 of Set 2 | namwala
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | idrinskoye
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | ambulu
# Processing Record 17 of Set 2 | shaoxing
# Processing Record 18 of Set 2 | kralendijk
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | pisco
# Processing Record 21 of Set 2 | osa
# Processing Record 22 of Set 2 | whitehorse
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | port blair
# Processing Record 27 of Set 2 | ginir
# Processing Record 28 of Set 2 | marsa matruh
# Processing Record 29 of Set 2 | rikitea
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | santo antonio do monte
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | zhigansk
# Processing Record 37 of Set 2 | kaeo
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | juneau
# Processing Record 41 of Set 2 | kahului
# Processing Record 42 of Set 2 | atasu
# Processing Record 43 of Set 2 | aklavik
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | vostok
# Processing Record 47 of Set 2 | bonavista
# Processing Record 48 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 2 | cuamba
# Processing Record 50 of Set 2 | skjervoy
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | bud
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | grenada
# Processing Record 6 of Set 3 | dicabisagan
# Processing Record 7 of Set 3 | ahuimanu
# Processing Record 8 of Set 3 | husavik
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 3 | amapa
# Processing Record 13 of Set 3 | gazli
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | lamar
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | olavarria
# Processing Record 18 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 3 | rapina
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | the valley
# Processing Record 25 of Set 3 | montauban
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | yerbogachen
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | viransehir
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | agdas
# Processing Record 32 of Set 3 | praia da vitoria
# Processing Record 33 of Set 3 | fryanovo
# Processing Record 34 of Set 3 | las varas
# Processing Record 35 of Set 3 | celestun
# Processing Record 36 of Set 3 | znamenskoye
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | vaini
# Processing Record 39 of Set 3 | bonthe
# Processing Record 40 of Set 3 | parintins
# Processing Record 41 of Set 3 | muros
# Processing Record 42 of Set 3 | wajima
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | bartica
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | kachiry
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | viedma
# Processing Record 50 of Set 3 | buraydah
# Processing Record 1 of Set 4 | tezu
# Processing Record 2 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 4 | general roca
# Processing Record 5 of Set 4 | marystown
# Processing Record 6 of Set 4 | bilma
# Processing Record 7 of Set 4 | imeni babushkina
# Processing Record 8 of Set 4 | lompoc
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | zhezkazgan
# Processing Record 11 of Set 4 | dakar
# Processing Record 12 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 4 | gamba
# Processing Record 14 of Set 4 | siguiri
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | khatanga
# Processing Record 17 of Set 4 | bloemfontein
# Processing Record 18 of Set 4 | lorengau
# Processing Record 19 of Set 4 | port augusta
# Processing Record 20 of Set 4 | asau
# Processing Record 21 of Set 4 | beyneu
# Processing Record 22 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | luchegorsk
# Processing Record 24 of Set 4 | erdaojiang
# Processing Record 25 of Set 4 | dikson
# Processing Record 26 of Set 4 | selfoss
# Processing Record 27 of Set 4 | te anau
# Processing Record 28 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | asyut
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | mildura
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 35 of Set 4 | shingu
# Processing Record 36 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 4 | yumen
# Processing Record 38 of Set 4 | chihuahua
# Processing Record 39 of Set 4 | sabya
# Processing Record 40 of Set 4 | mantua
# Processing Record 41 of Set 4 | takestan
# Processing Record 42 of Set 4 | payo
# Processing Record 43 of Set 4 | maniitsoq
# Processing Record 44 of Set 4 | grand gaube
# Processing Record 45 of Set 4 | hofn
# Processing Record 46 of Set 4 | kaposmero
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | nurota
# Processing Record 49 of Set 4 | pennadam
# Processing Record 50 of Set 4 | nouadhibou
# Processing Record 1 of Set 5 | benguela
# Processing Record 2 of Set 5 | coihaique
# Processing Record 3 of Set 5 | ferrol
# Processing Record 4 of Set 5 | batagay-alyta
# Processing Record 5 of Set 5 | nago
# Processing Record 6 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 5 | nuuk
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | nikolskoye
# Processing Record 11 of Set 5 | santo domingo
# Processing Record 12 of Set 5 | altona
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | halifax
# Processing Record 15 of Set 5 | boa vista
# Processing Record 16 of Set 5 | atikokan
# Processing Record 17 of Set 5 | longyearbyen
# Processing Record 18 of Set 5 | marzuq
# Processing Record 19 of Set 5 | jand
# Processing Record 20 of Set 5 | bagdarin
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | stolin
# Processing Record 23 of Set 5 | innisfail
# Processing Record 24 of Set 5 | sokolniki
# Processing Record 25 of Set 5 | darnah
# Processing Record 26 of Set 5 | sao felix do xingu
# Processing Record 27 of Set 5 | maloy
# Processing Record 28 of Set 5 | riyadh
# Processing Record 29 of Set 5 | tarrafal
# Processing Record 30 of Set 5 | tabuk
# Processing Record 31 of Set 5 | korsakov
# Processing Record 32 of Set 5 | troitskoye
# Processing Record 33 of Set 5 | tiznit
# Processing Record 34 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | fortuna
# Processing Record 36 of Set 5 | kozienice
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 5 | palu
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | morehead
# Processing Record 42 of Set 5 | port elizabeth
# Processing Record 43 of Set 5 | bulgan
# Processing Record 44 of Set 5 | buin
# Processing Record 45 of Set 5 | zhangye
# Processing Record 46 of Set 5 | guerrero negro
# Processing Record 47 of Set 5 | oranjestad
# Processing Record 48 of Set 5 | andros town
# Processing Record 49 of Set 5 | bereda
# Processing Record 50 of Set 5 | evensk
# Processing Record 1 of Set 6 | port macquarie
# Processing Record 2 of Set 6 | hilton head island
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | mankono
# Processing Record 5 of Set 6 | airai
# Processing Record 6 of Set 6 | labuhan
# Processing Record 7 of Set 6 | hobyo
# Processing Record 8 of Set 6 | yar-sale
# Processing Record 9 of Set 6 | rome
# Processing Record 10 of Set 6 | waipawa
# Processing Record 11 of Set 6 | burnie
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | new norfolk
# Processing Record 14 of Set 6 | merrill
# Processing Record 15 of Set 6 | les cayes
# Processing Record 16 of Set 6 | sorong
# Processing Record 17 of Set 6 | elat
# Processing Record 18 of Set 6 | synya
# Processing Record 19 of Set 6 | nyurba
# Processing Record 20 of Set 6 | hithadhoo
# Processing Record 21 of Set 6 | tomatlan
# Processing Record 22 of Set 6 | lubu
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | carbondale
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | hambantota
# Processing Record 27 of Set 6 | mar del plata
# Processing Record 28 of Set 6 | kathmandu
# Processing Record 29 of Set 6 | nchelenge
# Processing Record 30 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 31 of Set 6 | kitami
# Processing Record 32 of Set 6 | kaitong
# Processing Record 33 of Set 6 | wasilla
# Processing Record 34 of Set 6 | cubuk
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | nuevitas
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | ngaoundere
# Processing Record 39 of Set 6 | nemuro
# Processing Record 40 of Set 6 | sao filipe
# Processing Record 41 of Set 6 | tiksi
# Processing Record 42 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 6 | ngerengere
# Processing Record 44 of Set 6 | amuntai
# Processing Record 45 of Set 6 | moose factory
# Processing Record 46 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 6 | lagoa
# Processing Record 48 of Set 6 | orocue
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | iquique
# Processing Record 1 of Set 7 | fare
# Processing Record 2 of Set 7 | novoanninskiy
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | santa cruz de la palma
# Processing Record 5 of Set 7 | camabatela
# Processing Record 6 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 7 | umm lajj
# Processing Record 8 of Set 7 | egvekinot
# Processing Record 9 of Set 7 | kieta
# Processing Record 10 of Set 7 | green river
# Processing Record 11 of Set 7 | aasiaat
# Processing Record 12 of Set 7 | mailani
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | bilibino
# Processing Record 15 of Set 7 | hovd
# Processing Record 16 of Set 7 | banda aceh
# Processing Record 17 of Set 7 | cabildo
# Processing Record 18 of Set 7 | langham
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | kalynivka
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 7 | antofagasta
# Processing Record 24 of Set 7 | carballo
# Processing Record 25 of Set 7 | sao domingos
# Processing Record 26 of Set 7 | puerto baquerizo moreno
# Processing Record 27 of Set 7 | baykit
# Processing Record 28 of Set 7 | nishihara
# Processing Record 29 of Set 7 | thunder bay
# Processing Record 30 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 7 | port-cartier
# Processing Record 32 of Set 7 | jiancheng
# Processing Record 33 of Set 7 | ancud
# Processing Record 34 of Set 7 | portland
# Processing Record 35 of Set 7 | khash
# Processing Record 36 of Set 7 | dingle
# Processing Record 37 of Set 7 | benemerito de las americas
# Processing Record 38 of Set 7 | yingcheng
# Processing Record 39 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 7 | torbay
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 7 | macheng
# Processing Record 44 of Set 7 | knyaze-volkonskoye
# Processing Record 45 of Set 7 | pacifica
# Processing Record 46 of Set 7 | visnes
# Processing Record 47 of Set 7 | aksu
# Processing Record 48 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 49 of Set 7 | smithers
# Processing Record 50 of Set 7 | puerto colombia
# Processing Record 1 of Set 8 | ambanja
# Processing Record 2 of Set 8 | indianola
# Processing Record 3 of Set 8 | alofi
# Processing Record 4 of Set 8 | yambio
# Processing Record 5 of Set 8 | kudahuvadhoo
# Processing Record 6 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | langenburg
# Processing Record 8 of Set 8 | puerto quijarro
# Processing Record 9 of Set 8 | sakakah
# Processing Record 10 of Set 8 | ponta delgada
# Processing Record 11 of Set 8 | araguaina
# Processing Record 12 of Set 8 | solnechnyy
# Processing Record 13 of Set 8 | wanaka
# Processing Record 14 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 15 of Set 8 | los llanos de aridane
# Processing Record 16 of Set 8 | bougouni
# Processing Record 17 of Set 8 | hualmay
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | faya
# Processing Record 20 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 8 | beringovskiy
# Processing Record 22 of Set 8 | sur
# Processing Record 23 of Set 8 | mackay
# Processing Record 24 of Set 8 | yangambi
# Processing Record 25 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 8 | broome
# Processing Record 27 of Set 8 | great bend
# Processing Record 28 of Set 8 | storsteinnes
# Processing Record 29 of Set 8 | kirakira
# Processing Record 30 of Set 8 | bubaque
# Processing Record 31 of Set 8 | pachino
# Processing Record 32 of Set 8 | arlit
# Processing Record 33 of Set 8 | shakawe
# Processing Record 34 of Set 8 | teguldet
# Processing Record 35 of Set 8 | alihe
# Processing Record 36 of Set 8 | mount isa
# Processing Record 37 of Set 8 | gibara
# Processing Record 38 of Set 8 | enshi
# Processing Record 39 of Set 8 | chapais
# Processing Record 40 of Set 8 | la ronge
# Processing Record 41 of Set 8 | maceio
# Processing Record 42 of Set 8 | excelsior springs
# Processing Record 43 of Set 8 | ilulissat
# Processing Record 44 of Set 8 | harlingen
# Processing Record 45 of Set 8 | camara de lobos
# Processing Record 46 of Set 8 | coro
# Processing Record 47 of Set 8 | broken hill
# Processing Record 48 of Set 8 | beloha
# Processing Record 49 of Set 8 | henties bay
# Processing Record 50 of Set 8 | rio gallegos
# Processing Record 1 of Set 9 | tarakan
# Processing Record 2 of Set 9 | coquimbo
# Processing Record 3 of Set 9 | port-gentil
# Processing Record 4 of Set 9 | nelson bay
# Processing Record 5 of Set 9 | kalmunai
# Processing Record 6 of Set 9 | simbahan
# Processing Record 7 of Set 9 | ponta do sol
# Processing Record 8 of Set 9 | burgersdorp
# Processing Record 9 of Set 9 | kidal
# Processing Record 10 of Set 9 | san buenaventura
# Processing Record 11 of Set 9 | ixtapa
# Processing Record 12 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 9 | bernex
# Processing Record 14 of Set 9 | angoche
# Processing Record 15 of Set 9 | kontagora
# Processing Record 16 of Set 9 | sydney
# Processing Record 17 of Set 9 | matata
# Processing Record 18 of Set 9 | atar
# Processing Record 19 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 9 | shelburne
# Processing Record 21 of Set 9 | severo-kurilsk
# Processing Record 22 of Set 9 | rawson
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | saint-augustin
# Processing Record 25 of Set 9 | omboue
# Processing Record 26 of Set 9 | plettenberg bay
# Processing Record 27 of Set 9 | kampene
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | onalaska
# Processing Record 30 of Set 9 | strzegom
# Processing Record 31 of Set 9 | batouri
# Processing Record 32 of Set 9 | mabaruma
# Processing Record 33 of Set 9 | provideniya
# Processing Record 34 of Set 9 | faanui
# Processing Record 35 of Set 9 | bengkulu
# Processing Record 36 of Set 9 | byron bay
# Processing Record 37 of Set 9 | voorschoten
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | bedford
# Processing Record 40 of Set 9 | kilindoni
# Processing Record 41 of Set 9 | fort nelson
# Processing Record 42 of Set 9 | kyren
# Processing Record 43 of Set 9 | ambon
# Processing Record 44 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 9 | morondava
# Processing Record 46 of Set 9 | khanpur
# Processing Record 47 of Set 9 | leshukonskoye
# Processing Record 48 of Set 9 | college
# Processing Record 49 of Set 9 | aktas
# Processing Record 50 of Set 9 | cidreira
# Processing Record 1 of Set 10 | vaitape
# Processing Record 2 of Set 10 | coldingham
# Processing Record 3 of Set 10 | alice springs
# Processing Record 4 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 5 of Set 10 | kasempa
# Processing Record 6 of Set 10 | lagos de moreno
# Processing Record 7 of Set 10 | sassandra
# Processing Record 8 of Set 10 | rincon
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | sisimiut
# Processing Record 11 of Set 10 | srednekolymsk
# Processing Record 12 of Set 10 | flin flon
# Processing Record 13 of Set 10 | qandala
# Processing Record 14 of Set 10 | plyussa
# Processing Record 15 of Set 10 | namatanai
# Processing Record 16 of Set 10 | paamiut
# Processing Record 17 of Set 10 | teeli
# Processing Record 18 of Set 10 | santa maria
# Processing Record 19 of Set 10 | belmonte
# Processing Record 20 of Set 10 | graaff-reinet
# Processing Record 21 of Set 10 | healdsburg
# Processing Record 22 of Set 10 | crotone
# Processing Record 23 of Set 10 | sharjah
# Processing Record 24 of Set 10 | pimenteiras
# Processing Record 25 of Set 10 | vao
# Processing Record 26 of Set 10 | kashi
# Processing Record 27 of Set 10 | ailigandi
# Processing Record 28 of Set 10 | goba
# Processing Record 29 of Set 10 | alexandria
# Processing Record 30 of Set 10 | ramhormoz
# Processing Record 31 of Set 10 | otane
# Processing Record 32 of Set 10 | gizo
# Processing Record 33 of Set 10 | balkhash
# Processing Record 34 of Set 10 | lodwar
# Processing Record 35 of Set 10 | chifeng
# Processing Record 36 of Set 10 | manggar
# Processing Record 37 of Set 10 | sao gabriel da cachoeira
# Processing Record 38 of Set 10 | bowling green
# Processing Record 39 of Set 10 | marawi
# Processing Record 40 of Set 10 | anqiu
# Processing Record 41 of Set 10 | palmer
# Processing Record 42 of Set 10 | lalibela
# Processing Record 43 of Set 10 | nantucket
# Processing Record 44 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 45 of Set 10 | chivay
# Processing Record 46 of Set 10 | port lavaca
# Processing Record 47 of Set 10 | kincardine
# Processing Record 48 of Set 10 | general cepeda
# Processing Record 49 of Set 10 | udachnyy
# Processing Record 50 of Set 10 | san jose
# Processing Record 1 of Set 11 | kuytun
# Processing Record 2 of Set 11 | isangel
# Processing Record 3 of Set 11 | lazaro cardenas
# Processing Record 4 of Set 11 | soyo
# Processing Record 5 of Set 11 | hasaki
# Processing Record 6 of Set 11 | raudeberg
# Processing Record 7 of Set 11 | riverton
# Processing Record 8 of Set 11 | smoky lake
# Processing Record 9 of Set 11 | hervey bay
# Processing Record 10 of Set 11 | beni suef
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | akyab
# Processing Record 13 of Set 11 | mananara
# Processing Record 14 of Set 11 | eregli
# Processing Record 15 of Set 11 | kavos
# Processing Record 16 of Set 11 | south valley
# Processing Record 17 of Set 11 | eureka
# Processing Record 18 of Set 11 | saquarema
# Processing Record 19 of Set 11 | warrington
# Processing Record 20 of Set 11 | harrisonville
# Processing Record 21 of Set 11 | margate
# Processing Record 22 of Set 11 | kutulik
# Processing Record 23 of Set 11 | wilmington
# Processing Record 24 of Set 11 | alugan
# Processing Record 25 of Set 11 | saint-francois
# Processing Record 26 of Set 11 | clyde river
# Processing Record 27 of Set 11 | qasigiannguit
# Processing Record 28 of Set 11 | nzerekore
# Processing Record 29 of Set 11 | meulaboh
# Processing Record 30 of Set 11 | sao joao da barra
# Processing Record 31 of Set 11 | svetlogorsk
# Processing Record 32 of Set 11 | barras
# Processing Record 33 of Set 11 | cabedelo
# Processing Record 34 of Set 11 | puruaran
# Processing Record 35 of Set 11 | garowe
# Processing Record 36 of Set 11 | andenes
# Processing Record 37 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 11 | kharan
# Processing Record 39 of Set 11 | teahupoo
# Processing Record 40 of Set 11 | touros
# Processing Record 41 of Set 11 | olafsvik
# Processing Record 42 of Set 11 | panaba
# Processing Record 43 of Set 11 | vila velha
# Processing Record 44 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | khvastovichi
# Processing Record 46 of Set 11 | olga
# Processing Record 47 of Set 11 | hailar
# Processing Record 48 of Set 11 | pandan
# Processing Record 49 of Set 11 | sakata
# Processing Record 50 of Set 11 | kawalu
# Processing Record 1 of Set 12 | kjopsvik
# Processing Record 2 of Set 12 | taltal
# Processing Record 3 of Set 12 | collie
# Processing Record 4 of Set 12 | yarensk
# Processing Record 5 of Set 12 | kargasok
# Processing Record 6 of Set 12 | qidong
# Processing Record 7 of Set 12 | tawang
# Processing Record 8 of Set 12 | kerewan
# Processing Record 9 of Set 12 | siena
# Processing Record 10 of Set 12 | onitsha
# Processing Record 11 of Set 12 | visby
# Processing Record 12 of Set 12 | marsaxlokk
# Processing Record 13 of Set 12 | nabire
# Processing Record 14 of Set 12 | rio grande
# Processing Record 15 of Set 12 | charters towers
# Processing Record 16 of Set 12 | uskedal
# City not found. Skipping...
# Processing Record 17 of Set 12 | eyrarbakki
# Processing Record 18 of Set 12 | nakamura
# Processing Record 19 of Set 12 | grindavik
# Processing Record 20 of Set 12 | chicama
# Processing Record 21 of Set 12 | honiara
# Processing Record 22 of Set 12 | cockburn town
# Processing Record 23 of Set 12 | bela
# Processing Record 24 of Set 12 | bollnas
# Processing Record 25 of Set 12 | vista alegre
# Processing Record 26 of Set 12 | kupang
# Processing Record 27 of Set 12 | alpharetta
# Processing Record 28 of Set 12 | moundsville
# Processing Record 29 of Set 12 | laguna
# Processing Record 30 of Set 12 | kruisfontein
# Processing Record 31 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 12 | qaqortoq
# Processing Record 34 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 35 of Set 12 | kloulklubed
# Processing Record 36 of Set 12 | mori
# Processing Record 37 of Set 12 | saint-georges
# Processing Record 38 of Set 12 | campo verde
# Processing Record 39 of Set 12 | kavaratti
# Processing Record 40 of Set 12 | horsham
# Processing Record 41 of Set 12 | lakes entrance
# Processing Record 42 of Set 12 | ostersund
# Processing Record 43 of Set 12 | rocha
# Processing Record 44 of Set 12 | sturgeon bay
# Processing Record 45 of Set 12 | inuvik
# Processing Record 46 of Set 12 | qinhuangdao
# Processing Record 47 of Set 12 | sembe
# Processing Record 48 of Set 12 | challans
# Processing Record 49 of Set 12 | mareeba
# Processing Record 50 of Set 12 | pombas
# Processing Record 1 of Set 13 | ingham
# Processing Record 2 of Set 13 | hirara
# Processing Record 3 of Set 13 | ugoofaaru
# Processing Record 4 of Set 13 | wisconsin rapids
# Processing Record 5 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 13 | alghero
# Processing Record 7 of Set 13 | oyama
# Processing Record 8 of Set 13 | portalegre
# Processing Record 9 of Set 13 | sabzevar
# Processing Record 10 of Set 13 | sangar
# Processing Record 11 of Set 13 | kamenka
# Processing Record 12 of Set 13 | high level
# Processing Record 13 of Set 13 | porto santo
# Processing Record 14 of Set 13 | saldanha
# Processing Record 15 of Set 13 | francisco sa
# Processing Record 16 of Set 13 | amatenango del valle
# Processing Record 17 of Set 13 | someshwar
# Processing Record 18 of Set 13 | weifang
# Processing Record 19 of Set 13 | west bay
# Processing Record 20 of Set 13 | redmond
# Processing Record 21 of Set 13 | cairns
# Processing Record 22 of Set 13 | murray bridge
# Processing Record 23 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 13 | imeni poliny osipenko
# Processing Record 25 of Set 13 | carnduff
# Processing Record 26 of Set 13 | acajutla
# Processing Record 27 of Set 13 | ankang
# Processing Record 28 of Set 13 | caravelas
# Processing Record 29 of Set 13 | lyuban
# Processing Record 30 of Set 13 | aracati
# Processing Record 31 of Set 13 | gavle
# Processing Record 32 of Set 13 | naryan-mar
# Processing Record 33 of Set 13 | banyo
# Processing Record 34 of Set 13 | spirit river
# Processing Record 35 of Set 13 | talaya
# Processing Record 36 of Set 13 | gaya
# Processing Record 37 of Set 13 | svetlaya
# Processing Record 38 of Set 13 | tessalit
# Processing Record 39 of Set 13 | port moresby
# Processing Record 40 of Set 13 | markova
# Processing Record 41 of Set 13 | buenos aires
# Processing Record 42 of Set 13 | deputatskiy
# Processing Record 43 of Set 13 | buala
# Processing Record 44 of Set 13 | catuday
# Processing Record 45 of Set 13 | camopi
# Processing Record 46 of Set 13 | arganil
# Processing Record 47 of Set 13 | bandarbeyla
# Processing Record 48 of Set 13 | sola
# Processing Record 49 of Set 13 | basco
# Processing Record 50 of Set 13 | presidente venceslau
# Processing Record 1 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 14 | takoradi
# Processing Record 3 of Set 14 | ilhabela
# Processing Record 4 of Set 14 | vizianagaram
# Processing Record 5 of Set 14 | sterling
# Processing Record 6 of Set 14 | arkhangelos
# City not found. Skipping...
# Processing Record 7 of Set 14 | ornskoldsvik
# Processing Record 8 of Set 14 | shemonaikha
# Processing Record 9 of Set 14 | mbala
# Processing Record 10 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 14 | hami
# Processing Record 12 of Set 14 | keuruu
# Processing Record 13 of Set 14 | tikrit
# Processing Record 14 of Set 14 | kharp
# Processing Record 15 of Set 14 | idritsa
# Processing Record 16 of Set 14 | arkhara
# Processing Record 17 of Set 14 | palimbang
# Processing Record 18 of Set 14 | tual
# Processing Record 19 of Set 14 | amahai
# Processing Record 20 of Set 14 | adrar
# Processing Record 21 of Set 14 | victor harbor
# Processing Record 22 of Set 14 | gusau
# Processing Record 23 of Set 14 | vrangel
# Processing Record 24 of Set 14 | adet
# Processing Record 25 of Set 14 | misratah
# Processing Record 26 of Set 14 | necochea
# Processing Record 27 of Set 14 | christiana
# Processing Record 28 of Set 14 | shizunai
# Processing Record 29 of Set 14 | tibati
# Processing Record 30 of Set 14 | anadyr
# Processing Record 31 of Set 14 | okhotsk
# Processing Record 32 of Set 14 | parauna
# Processing Record 33 of Set 14 | mandeville
# Processing Record 34 of Set 14 | luwuk
# Processing Record 35 of Set 14 | tromso
# Processing Record 36 of Set 14 | aromashevo
# Processing Record 37 of Set 14 | ullapool
# Processing Record 38 of Set 14 | sambava
# Processing Record 39 of Set 14 | batticaloa
# Processing Record 40 of Set 14 | bonfim
# Processing Record 41 of Set 14 | nazca
# Processing Record 42 of Set 14 | guadalupe y calvo
# Processing Record 43 of Set 14 | rock springs
# Processing Record 44 of Set 14 | altay
# Processing Record 45 of Set 14 | hanzhong
# Processing Record 46 of Set 14 | aksarka
# Processing Record 47 of Set 14 | inhambane
# Processing Record 48 of Set 14 | orlik
# Processing Record 49 of Set 14 | olinda
# Processing Record 50 of Set 14 | ulladulla
# Processing Record 1 of Set 15 | ajdabiya
# Processing Record 2 of Set 15 | sembabule
# Processing Record 3 of Set 15 | putai
# Processing Record 4 of Set 15 | shupiyan
# Processing Record 5 of Set 15 | burica
# City not found. Skipping...
# Processing Record 6 of Set 15 | evans
# Processing Record 7 of Set 15 | talara
# Processing Record 8 of Set 15 | windhoek
# Processing Record 9 of Set 15 | bemidji
# Processing Record 10 of Set 15 | la cruz
# Processing Record 11 of Set 15 | barranca de upia
# Processing Record 12 of Set 15 | kedrovyy
# Processing Record 13 of Set 15 | taoudenni
# Processing Record 14 of Set 15 | noumea
# Processing Record 15 of Set 15 | montorio al vomano
# Processing Record 16 of Set 15 | diffa
# Processing Record 17 of Set 15 | katy
# Processing Record 18 of Set 15 | colares
# Processing Record 19 of Set 15 | kismayo
# Processing Record 20 of Set 15 | nome
# Processing Record 21 of Set 15 | boende
# Processing Record 22 of Set 15 | kushima
# Processing Record 23 of Set 15 | katha
# City not found. Skipping...
# Processing Record 24 of Set 15 | monrovia
# Processing Record 25 of Set 15 | governador valadares
# Processing Record 26 of Set 15 | comodoro rivadavia
# Processing Record 27 of Set 15 | suixi
# Processing Record 28 of Set 15 | jiayuguan
# Processing Record 29 of Set 15 | carutapera
# Processing Record 30 of Set 15 | onda
# Processing Record 31 of Set 15 | poronaysk
# Processing Record 32 of Set 15 | rochegda
# Processing Record 33 of Set 15 | bambanglipuro
# Processing Record 34 of Set 15 | shenjiamen
# Processing Record 35 of Set 15 | pangoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 679

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kodiak      US  57.79 -152.41     42.80        87          90
# 1      East London      ZA -33.02   27.91     70.27        91         100
# 2     Punta Arenas      CL -53.15  -70.92     62.60        55          75
# 3         Tasiilaq      GL  65.61  -37.64     26.60        68         100
# 4            Bluff      NZ -46.60  168.33     56.75        76          49
# ..             ...     ...    ...     ...       ...       ...         ...
# 674      Poronaysk      RU  49.22  143.12     17.40        89         100
# 675       Rochegda      RU  62.80   43.25     33.42        93         100
# 676  Bambanglipuro      ID  -7.95  110.28     78.64        82         100
# 677     Shenjiamen      CN  29.96  122.30     57.15        77          98
# 678         Pangoa      PE -12.12  -73.00     70.95        95          95
#
#      Wind Speed Current Description
# 0         16.11          light rain
# 1         14.70          light rain
# 2         27.51       broken clouds
# 3          8.05          light snow
# 4         14.34    scattered clouds
# ..          ...                 ...
# 674        2.84     overcast clouds
# 675        6.49     overcast clouds
# 676        2.28          light rain
# 677       14.52     overcast clouds
# 678        1.68          light rain
#
# [679 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# ******** Deliverable 1 - Retrieve Weather Data Complete *****
